# %%
import pandas as pd
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
from matplotlib.figure import Figure
from matplotlib.font_manager import FontProperties

# %%
df1= pd.read_csv('/Users/danait/documents/galvanize/capstone/global_ecological_footprint/data/countries.csv', header= 0)

# %%
# df1.info()
# df1.columns

# %%
df2= df1.copy()

# %%
# df.head(2)

# %%
df2['HDI'].isnull().sum()
# Out:
# 16

# %%
# trying to see which rows in the HDI column have NaN value 
# pd.isna(df['HDI'])

# %%
### returns all the NaN values in the HDI columns 
# df[(pd.isna(df['HDI'])== True)]

# %%
# drop all the rows that are at this row index not in inplace 
df2.drop([7, 18, 24, 115, 120, 184], inplace= False)
# number of all the NaN values in the df
df2.isnull().sum().sum()
# Out:
# 181

# %%
# df.isnull().values.any()

# %%
df2['Cropland Footprint'].isnull().sum()
# Out:
# 15

# %%
#df[(pd.isna(df['Cropland Footprint'])== True)]

# %%
# drop all the rows with NaN values for some of the columns inplace 
df2.drop([4, 7, 18, 24, 29, 30, 49, 57, 60, 63, 70, 115,123, 128, 145, 184], inplace= True)
df2.drop([120], inplace= True)
df2.isnull().sum().sum()
# Out:
# 16

# %%
#df[(pd.isna(df['Cropland Footprint'])== True)]

# %%
# df.info()

# %%
# the sum off all the NaN values under all the dataframe
df2.isnull().sum().sum()
# Out:
# 16

# %%
# df[(pd.isna(df['HDI'])== True)]

# %%
df_HDInan= df2[(pd.isna(df['HDI'])== True)]
#df_HDInan

# %%
NaNHDI= {'Cayman Islands': 0.888, "Côte d'Ivoire": 0.516 ,'French Guiana':0.789, 'Guadeloupe':0.841, "Korea, Democratic People's Republic of": 0.733, 'Martinique':0.854, 'Réunion':0.836 ,'Somalia':0.364}

# %%
def HDI_fillna (NaNHDI,df2):
    while df2['HDI'].isnull().sum() >0:
        fillna_value={}
        for k,v in NaNHDI.items():
            fillna_value['HDI']=v
            df2.fillna(fillna_value, inplace= True, limit=1)
        return df2
        
HDI_fillna(NaNHDI,df_HDInan)
df_HDInan
# Out:
#                                     Country         Region  \
# 33                           Cayman Islands  Latin America
# 43                            Côte d'Ivoire         Africa
# 62                            French Guiana  Latin America
# 71                               Guadeloupe  Latin America
# 91   Korea, Democratic People's Republic of   Asia-Pacific
# 108                              Martinique  Latin America
# 139                                 Réunion         Africa
# 156                                 Somalia         Africa
#
#      Population (millions)    HDI GDP per Capita  Cropland Footprint  \
# 33                    0.06  0.888            NaN                0.36
# 43                   19.84  0.516      $1,016.83                0.51
# 62                    0.24  0.789            NaN                0.07
# 71                    0.46  0.841            NaN                0.11
# 91                   24.76  0.733            NaN                0.28
# ...

# %%
# df[(pd.isna(df['GDP per Capita'])== True)]

# %%
NaNGDP= {'Cayman Islands': "$81124.51",'French Guiana':"$18313", 'Guadeloupe':"$25479", "Korea, Democratic People's Republic of": "$1700", 'Martinique':"$30056", 'Réunion':"$6200" ,'Somalia':'$314.54', 'Syrian Arab Republic':'$2032.62' }

# %%
def GDP_fillna (NaNGDP,df):
    while df2['GDP per Capita'].isnull().sum() >0:
        fillna_value={}
        for k,v in NaNGDP.items():
            fillna_value['GDP per Capita']=v
            df2.fillna(fillna_value, inplace= True, limit=1)
        return df2
        
GDP_fillna(NaNGDP,df2)
HDI_fillna(NaNHDI,df2)

# %%
df2.isnull().sum().sum()
# Out:
# 0

# %%
# making sure the rows were filled correctly
# df.iloc[[43,62,63,71],:]

# %%
# df.isnull().values.any()

# %%
# df[['HDI', 'GDP per Capita']]

# %%
# df.info()

# %%
# df.plot.scatter(x= 'Population (millions)', y= 'Biocapacity Deficit or Reserve')
# plt.tight_layout()

# %%
# doesnt work 
# df['HDI'].apply(pd.to_numeric, errors='coerce' )

# %%
# pd.to_numeric(df["HDI"], downcast="float")

# %%
# df.info()

# %%
# df['GDP per Capita'].isnull().sum()

# %%
# type(df['GDP per Capita'])

# %%
# df['GDP per Capita'].tolist()
# for i in (df['GDP per Capita'].tolist()):
#     lst= []
#     i.replace('$', '')
#     lst.append(i)
    

# lst

# %%
# '''2 (going by gdp and population) scatter plots for all the countries 
# total ecological footprint

# 2 line graph of total biocapactiy vs. ecological footprint - for gdp and population 


# bar chart of top ten ecologically deficit countries 



# bar chart of top ten countires with ecological reserve


# -map of biocapacity deficit or reserve/folium 


# some graphs for by region (continents) 


# lots of plotting 
# learning how to create heat maps using folium 

# would like to work on read me by tomorrow 

# '''

# %%
df= df2
elem= '$'
column= "GDP per Capita"

def clean_column_values(elem,df,col):
  final_col_output= []
  for value in (df[str(col)].tolist()):
    joinstring=''
    for item in value:
      if item.isnumeric()==True or item== ".":
        joinstring+=item
    final_col_output.append(float(joinstring))
  df[str(col)]= final_col_output
  return df
clean_column_values(elem,df2,column)
# Out:
#                                Country                    Region  \
# 0                          Afghanistan  Middle East/Central Asia
# 1                              Albania   Northern/Eastern Europe
# 2                              Algeria                    Africa
# 3                               Angola                    Africa
# 5                            Argentina             Latin America
# ..                                 ...                       ...
# 182  Venezuela, Bolivarian Republic of             Latin America
# 183                           Viet Nam              Asia-Pacific
# 185                              Yemen  Middle East/Central Asia
# 186                             Zambia                    Africa
# 187                           Zimbabwe                    Africa
#
#      Population (millions)       HDI  GDP per Capita  Cropland Footprint  \
# 0                    29.82  0.460000          614.66                0.30
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 171 entries, 0 to 187
# Data columns (total 21 columns):
# Country                           171 non-null object
# Region                            171 non-null object
# Population (millions)             171 non-null float64
# HDI                               171 non-null float64
# GDP per Capita                    171 non-null float64
# Cropland Footprint                171 non-null float64
# Grazing Footprint                 171 non-null float64
# Forest Footprint                  171 non-null float64
# Carbon Footprint                  171 non-null float64
# Fish Footprint                    171 non-null float64
# Total Ecological Footprint        171 non-null float64
# Cropland                          171 non-null float64
# Grazing Land                      171 non-null float64
# Forest Land                       171 non-null float64
# Fishing Water                     171 non-null float64
# ...

# %%
df= df2.copy()
df3= df2.copy()

# %%
plt.figure()
fig= plt.figure(figsize=(17,12), edgecolor= 'black')
 
ax1= fig.add_subplot(2,1,1)
ax1.scatter(df3['Population (millions)'],df3["Total Ecological Footprint"], color= "gray")
ax1.set_xlabel("Population (millions)", fontsize= 20)
ax1.set_ylabel("Total Ecological Footprint", fontsize= 20)
ax1.set_title("Total Ecological Footprint as Population Increases", fontsize=18, fontweight= "bold")
ax1.set_xlim(0,150)
ax1.set_ylim(0,10)
# plt.figure()
ax1a= ax1.inset_axes([0.6, 0.65, 0.40, .35])
# ax1.axhline(y=0, xmin=0, ls= "--")
 
ax1a.scatter(df3['Population (millions)'],df3["Total Ecological Footprint"])





ax2=fig.add_subplot(2,1,2)
ax2.scatter(df3['GDP per Capita'],df3["Total Ecological Footprint"], color= "red")
ax2.set_xlabel("GDP per Capita", fontsize= 20)
ax2.set_ylabel("Total Ecological Footprint ", fontsize= 20)
ax2.set_title("Total Ecological Footprint as GDP Increases", fontsize=18, fontweight= "bold")
ax2.set_xlim(200,20000)
ax2.set_ylim(0,10)
# plt.figure()
ax2a= ax2.inset_axes([0.6, 0.65, 0.40, .35])
# ax2.axhline(y=0, xmin=0, ls= "--")

ax2a.scatter(df3['GDP per Capita'],df3["Total Ecological Footprint"])
plt.tight_layout()
plt.savefig("test3.png")
plt.show()

plt.close()

# %%
plt.figure()
fig= plt.figure(figsize=(17,12), edgecolor= 'black')
 
ax1= fig.add_subplot(2,1,1)
ax1.scatter(df3['Population (millions)'],df3["Biocapacity Deficit or Reserve"], color= "gray")
ax1.set_xlabel("Population (millions)", fontsize= 20)
ax1.set_ylabel("Biocapacity Deficit or Reserve", fontsize= 20)
ax1.set_title("Biocapacity Deficit or Reserve as Population Increases", fontsize=18, fontweight= "bold")
ax1.set_xlim(0,200)
ax1.set_ylim(-10,10)
# plt.figure()
ax1a= ax1.inset_axes([0.6, 0.65, 0.40, .35])
ax1.axhline(y=0, xmin=0, ls= "--")
 
ax1a.scatter(df3['Population (millions)'],df3["Biocapacity Deficit or Reserve"])





ax2=fig.add_subplot(2,1,2)
ax2.scatter(df3['GDP per Capita'],df3["Biocapacity Deficit or Reserve"], color= "red")
ax2.set_xlabel("GDP per Capita", fontsize= 20)
ax2.set_ylabel("Biocapacity Deficit or Reserve", fontsize= 20)
ax2.set_title("Biocapacity Deficit or Reserve as GDP Increases", fontsize=18, fontweight= "bold")
ax2.set_xlim(200,2000)
ax2.set_ylim(-10,10)
# plt.figure()
ax2a= ax2.inset_axes([0.6, 0.65, 0.40, .35])
ax2.axhline(y=0, xmin=0, ls= "--")

ax2a.scatter(df3['GDP per Capita'],df3["Biocapacity Deficit or Reserve"])
plt.tight_layout()
plt.savefig("test2.png")
plt.show()

plt.close()

# %%
color1= "gray"
color2= "gray"

x= df['Population (millions)']
y= df["Total Ecological Footprint"]
xtitle= "Population (millions)"
ytitle= "Total Ecological Footprint"
title= "Ecologial Footprint as Population Increases"
xlim= (0,150)
ax1_location= [0.6, 0.55, 0.40, .45]
ylim=(-.50,16.5) 
def scatter_plot (ax,color1, x, y,xtitle, ytitle, title, xlim,  ylim, ax1_location):
    fig= plt.figure(figsize=(12,7))
    ax= fig.add_subplot(111)
    ax.scatter(x,y, color= color1)
    ax.set_xlabel(xtitle, fontsize= 20)
    ax.set_ylabel(ytitle, fontsize= 20)
    ax.set_title(title, fontsize=22, fontweight= "bold")
    ax.set_xlim(xlim)
    ax.set_ylim(ylim)
    plt.figure()
    
    ax1= ax.inset_axes(ax1_location)
    plt.savefig('Ecologial_Footprint_as_population_increases.png', bbox_inches='tight') 
    ax1.scatter(x, y )
    return None
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1132-ec1ba3461d22> in <module>
#      28
#      29
# ---> 30 (scatter_plot (ax,color, x, y,xtitle, ytitle, title, xlim, ylim, ax1_location)).savefig('Ecologial_Footprint_as_population_increases.png', bbox_inches='tight')
#
# AttributeError: 'NoneType' object has no attribute 'savefig'

# %%
color= "red"

x= df['GDP per Capita']
y= df["Total Ecological Footprint"]
xtitle= "GDP per Capita"
ytitle= "Total Ecological Footprint"
title= "Ecologial Footprint as GDP increases"
xlim= (200,60000)
ylim= (-.50,16.5) 
ax1_location= [0.6, 0.65, 0.40, .35]
scatter_plot (ax,color, x, y, xtitle, ytitle, title, xlim, ylim, ax1_location) 
# # plt.savefig('Ecologial_Footprint_as_GDP_increases.png', bbox_inches='tight')

# %%
# 2 line graph of total biocapactiy vs. ecological footprint - for gdp and population

# %%
# fig= plt.figure(figsize=(12,7))
# ax= fig.add_subplot(111)

# font = {'family' : 'normal',
#         'weight' : 'bold',
#         'size'   : 22}
# ax.hist( df["Total Ecological Footprint"], bins=50)
# ax.set_xlabel("Population (millions)", fontsize= 20)    
# ax.set_ylabel("Total Ecological Footprint", fontsize= 20)
# ax.set_title("Ecologial Footprint as population increases", fontsize= 22, fontweight= "bold")
# ax.set_xlim(0,200)

# ax1= ax.inset_axes([0.0, 0.50, 0.30, .35])
# ax1.hist(df["Total Ecological Footprint"], color= "gray" ) 
# ax1= fig.add_subplot(221)

# %%
# df.describe()

# %%
color= "gray"

x= df['GDP per Capita']
y= df["Total Biocapacity"]
xtitle= "GDP per Capita"
ytitle= "Biocapacity"
title= "Total Biocapacity"
xlim= (200,60000)
ylim= (0,60)
ax1_location= [0.6, 0.65, 0.40, .35]
ylim= (-.50,30) 
scatter_plot (ax,color, x, y, xtitle, ytitle, title, xlim, ylim, ax1_location)

# %%
color= "gray"

x= df['Population (millions)']
y= df["Total Biocapacity"]
xtitle= "Population (millions)"
ytitle= "Biocapacity"
title= "Total Biocapacity"
xlim= (0,200)
ax1_location= [0.6, 0.65, 0.40, .35]
ylim= (-.50,30) 
scatter_plot (ax,color, x, y, xtitle, ytitle, title, xlim, ylim, ax1_location)

# %%
df[df['Total Biocapacity'] == df['Total Biocapacity'].max()]
# Out:
#           Country         Region  Population (millions)    HDI  \
# 62  French Guiana  Latin America                   0.24  0.789
#
#     GDP per Capita  Cropland Footprint  Grazing Footprint  Forest Footprint  \
# 62         18313.0                0.07               0.06              0.46
#
#     Carbon Footprint  Fish Footprint  ...  Cropland  Grazing Land  \
# 62              1.58            0.17  ...      0.07          0.06
#
#     Forest Land  Fishing Water  Urban Land  Total Biocapacity  \
# 62        95.16          16.07         0.0             111.35
#
#     Biocapacity Deficit or Reserve  Earths Required  Countries Required  \
# 62                          109.01             1.35                0.02
#
#     Data Quality
# 62            3L
#
# [1 rows x 21 columns]

# %%
color= "gray"

x= df['Population (millions)']
y= df["Biocapacity Deficit or Reserve"]
xtitle= "Population (millions)"
ytitle= "Biocapacity Deficit or Reserve"
title= "Biocapacity Def or Res as Population Increases"
xlim= (0,100)
ax1_location= [0.6, 0.65, 0.40, .35]
ylim= (-5,5) 
scatter_plot (ax,color, x, y, xtitle, ytitle, title, xlim, ylim, ax1_location) 
plt.save

# %%
# top ten densily populated counties
color= "red"

x= df['GDP per Capita']
y= df["Biocapacity Deficit or Reserve"]
xtitle= "GDP per Capita"
ytitle= "Biocapacity Deficit or Reserve"
title= "Biocapacity Def or Res as GDP Increases"
xlim= (200,6000)
ax1_location= [0.6, 0.65, 0.40, .35]
ylim= (-5,5) 
scatter_plot (ax,color, x, y, xtitle, ytitle, title, xlim, ylim, ax1_location)

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Population (millions)', 'HDI', 'GDP per Capita',
#        'Cropland Footprint', 'Grazing Footprint', 'Forest Footprint',
#        'Carbon Footprint', 'Fish Footprint', 'Total Ecological Footprint',
#        'Cropland', 'Grazing Land', 'Forest Land', 'Fishing Water',
#        'Urban Land', 'Total Biocapacity', 'Biocapacity Deficit or Reserve',
#        'Earths Required', 'Countries Required', 'Data Quality'],
#       dtype='object')

# %%
df_region= df.groupby("Region").sum()[["Cropland Footprint", "Grazing Footprint", "Forest Footprint", "Carbon Footprint", "Fish Footprint", "Total Ecological Footprint"]]
df_region
# Out:
#                           Cropland Footprint  Grazing Footprint  \
# Region
# Africa                                 19.48              11.48
# Asia-Pacific                           16.53               6.70
# European Union                         23.59               6.25
# Latin America                          14.85              12.57
# Middle East/Central Asia               13.77               4.87
# North America                           2.59               0.63
# Northern/Eastern Europe                 7.79               1.76
#
#                           Forest Footprint  Carbon Footprint  Fish Footprint  \
# Region
# Africa                               15.50             29.04            4.69
# Asia-Pacific                         10.92             41.25            5.83
# European Union                       15.40             78.34            2.78
# Latin America                        11.91             56.41            4.37
# ...

# %%
def clean_col_name(df_, replace, replace_with):
    cols= df_.columns.tolist()
    cols= [col.replace(replace,replace_with) for col in cols]
    df_.columns= cols
    return df_
x= clean_col_name(df_region, "Footprint", "").columns
df_region.iloc[0,:]
# Out:
# Cropland             19.48
# Grazing              11.48
# Forest               15.50
# Carbon               29.04
# Fish                  4.69
# Total Ecological     82.18
# Name: Africa, dtype: float64

# %%
# creates random colors: matplotlib.colors.rgb_to_hsv(np.random.random(size=3))
fig= plt.figure()
plt.style.use("seaborn-darkgrid")
row= 0
for elem in df_region.index:
    plt.figure(1,1,row+1)
    
    
    
    region= pd.DataFrame({ 'column':clean_col_name(df_region, "Footprint", "").columns, "value":df_region.iloc[row,:]})
    row+=1
    plt.plot(region["column"], region["value"], label= elem)
    size=22
    plt.ylabel('Ecological footprint by category')
    plt.title('Total Regional Ecological Footprint',fontsize=22, fontweight= "bold" )
    params = {
          'figure.figsize': (15,8),
          'axes.labelsize': 20,
          'axes.titlesize': 22,
          'xtick.labelsize': size*0.75,
          'ytick.labelsize': size*0.75,
          'axes.titlepad': 25}
    plt.rcParams.update(params)
plt.legend(fancybox=True, fontsize=17)

# %%
from matplotlib.font_manager import FontProperties
fig= plt.figure()
plt.style.use("seaborn-darkgrid")
row= 0
for elem in df_region.index:
    plt.figure(1,1,row+1)
    
    
    
    region= pd.DataFrame({ 'column':clean_col_name(df_region, "Footprint", "").columns, "value":df_region.iloc[row,:]})
    row+=1
    plt.plot(region["column"], region["value"], label= elem)
plt.legend(fancybox=True, fontsize=13)

# %%
# df.head(2)

# %%
df_region_biocapacity= df.groupby("Region").sum()[["Cropland", "Grazing Land", "Forest Land", "Fishing Water", "Urban Land", "Total Biocapacity"]]
df_region_biocapacity
# Out:
#                           Cropland  Grazing Land  Forest Land  Fishing Water  \
# Region
# Africa                       15.20         29.78        51.11          18.19
# Asia-Pacific                 16.25         17.73        32.81          12.32
# European Union               25.96          2.92        29.36           9.39
# Latin America                15.26         19.18       282.18          46.42
# Middle East/Central Asia      6.92          6.52         2.28           5.09
# North America                 4.60          0.57        10.69           3.74
# Northern/Eastern Europe       7.56          1.95        14.34           2.04
#
#                           Urban Land  Total Biocapacity
# Region
# Africa                          1.98             116.27
# Asia-Pacific                    2.29              81.46
# European Union                  3.25              70.90
# Latin America                   1.80             364.84
# ...

# %%
def reginal_biocapacity(df_region, title, ytitle):
    '''takes a dataframe, uses the columns as lables on the x-axis
    and plots the rows at each axis
    '''
    fig= plt.figure(figsize= (10,8))
    plt.style.use("seaborn-darkgrid")
    row= 0
    for elem in df_region.index:
        plt.figure(1,1,row+1)
        region= pd.DataFrame({ 'column':clean_col_name(df_region, "Footprint", "").columns, "value":df_region.iloc[row,:]})
        row+=1
        plt.plot(region["column"], region["value"], label= elem)
    plt.legend(fancybox=True, fontsize=18)
    plt.ylabel(ytitle)
    plt.title(title,fontsize=22, fontweight= "bold" )
#     matplotlib.rc('axes', xsize=12)
    size=22
    params = {
          'figure.figsize': (15,8),
          'axes.labelsize': 20,
          'axes.titlesize': 22,
          'xtick.labelsize': size*0.75,
          'ytick.labelsize': size*0.75,
          'axes.titlepad': 25}
    plt.rcParams.update(params)
    return None
reginal_biocapacity(df_region_biocapacity," Regional Biocapacity")
plt.savefig('"region_biocapacity"', bbox_inches='tight')
# plt.save("region_biocapacity")

# %%
# df_region_biocapacity_pop= df.groupby("Region").sum()[["Population (millions)", "Total Biocapacity", "GDP per Capita","Total Ecological Footprint"]]
# df_region_biocapacity_pop
df_region_biocap_ecolog= df.groupby("Region").sum()[["Total Biocapacity",'Total Ecological Footprint','Biocapacity Deficit or Reserve']]

# %%
df_region_biocap_ecolog
# Out:
#                           Total Biocapacity  Total Ecological Footprint  \
# Region
# Africa                               116.27                       82.18
# Asia-Pacific                          81.46                       83.49
# European Union                        70.90                      129.63
# Latin America                        364.84                      101.88
# Middle East/Central Asia              22.41                       93.25
# North America                         19.77                       16.39
# Northern/Eastern Europe               26.41                       40.18
#
#                           Biocapacity Deficit or Reserve
# Region
# Africa                                             34.10
# Asia-Pacific                                       -2.02
# European Union                                    -58.74
# Latin America                                     262.98
# Middle East/Central Asia                          -70.87
# ...

# %%
# creates random colors: matplotlib.colors.rgb_to_hsv(np.random.random(size=3))
fig= plt.figure()
plt.style.use("seaborn-darkgrid")
row= 0
for elem in df_region_biocap_ecolog.index:
    plt.figure(1,1,row+1)
    
    
    
    region= pd.DataFrame({ 'column':clean_col_name(df_region_biocap_ecolog, "Footprint", "").columns, "value":df_region_biocap_ecolog.iloc[row,:]})
    row+=1
    plt.plot(region["column"], region["value"], label= elem)
    size=22
    plt.ylabel('global hectares per person')
    plt.title('Regional Biocapacity vs. Ecological Demand',fontsize=22, fontweight= "bold" )
    params = {
          'figure.figsize': (15,8),
          'axes.labelsize': 20,
          'axes.titlesize': 22,
          'xtick.labelsize': size*0.75,
          'ytick.labelsize': size*0.75,
          'axes.titlepad': 25}
    plt.rcParams.update(params)
plt.legend(fancybox=True, fontsize=17)
#plt.savefig('region_biocap_vs_ecology_demand', bbox_inches='tight')

# %%
#DOESNT WORK 
# regional biocapacity and footprint with added population and gdp 
df_region_biocap_ecolog_popGDP= df.groupby("Region").sum()[["Population (millions)","GDP per Capita","Total Biocapacity",'Total Ecological Footprint','Biocapacity Deficit or Reserve']]

# %%
sort_top10_GDP_countries= df.sort_values(["GDP per Capita"], ascending= False)
top_10_GDPcountries= sort_top10_GDP_countries[["Country","GDP per Capita","Total Biocapacity","Total Ecological Footprint","Biocapacity Deficit or Reserve" ]].set_index("Country").head(5)
top_10_GDPcountries
# Out:
#                 GDP per Capita  Total Biocapacity  Total Ecological Footprint  \
# Country
# Luxembourg           114665.00               1.68                       15.82
# Qatar                 99431.50               1.24                       10.80
# Switzerland           88506.20               1.30                        5.79
# Cayman Islands        81124.51               0.32                        5.65
# Australia             66604.20              16.57                        9.31
#
#                 Biocapacity Deficit or Reserve
# Country
# Luxembourg                              -14.14
# Qatar                                    -9.56
# Switzerland                              -4.48
# Cayman Islands                           -5.33
# Australia                                 7.26

# %%
import numpy as np
import matplotlib.pyplot as plt
 
# set width of bar
barWidth = 0.15
 
# set height of bar
labels= df_region_biocap_ecolog.index
bar1= df_region_biocap_ecolog["Total Biocapacity"]
# bar2= df_region_biocap_ecolog["Total Ecological Footprint"]
bar3= df_region_biocap_ecolog["Biocapacity Deficit or Reserve"]
 
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
 
# Make the plot
plt.bar(r1, bars1, color='#7f6d5f', width=barWidth, edgecolor='white', label='Total Biocapacity')
plt.bar(r2, bars2, color='#557f3d', width=barWidth, edgecolor='white', label='Total Ecological Footprint')
plt.bar(r3, bars3, color='#2d7f5e', width=barWidth, edgecolor='white', label='Biocapacity Deficit or Reserve')
 
# Add xticks on the middle of the group bars
# plt.xlabel('group', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(bars1))], labels)
 
# Create legend & Show graphic
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-897-38485f088914> in <module>
#      12
#      13 # Set position of bar on X axis
# ---> 14 r1 = np.arange(len(bars1))
#      15 r2 = [x + barWidth for x in r1]
#      16 r3 = [x + barWidth for x in r2]
#
# NameError: name 'bars1' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
 
# set width of bar
barWidth = 0.15
 
# set height of bar
labels= top_10_GDPcountries.index
bar1= top_10_GDPcountries["GDP per Capita"]
bar2 = top_10_GDPcountries["Total Biocapacity"]
bar3= top_10_GDPcountries["Total Ecological Footprint"]
bar4= top_10_GDPcountries["Biocapacity Deficit or Reserve"]
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
r3 =[x + barWidth for x in r2]
r4= [x + barWidth for x in r3]
 
# Make the plot
plt.bar(r1, bars1, color='#7f6d5f', width=barWidth, edgecolor='white', label='GDP per Capita')
plt.bar(r2, bars2, color='#557f2d', width=barWidth, edgecolor='white', label='Total Biocapacity')
plt.bar(r3, bars3, color='#2d7f5e', width=barWidth, edgecolor='white', label='Total Ecological Footprint')
plt.bar(r4, bars3, color='#6d7f5e', width=barWidth, edgecolor='white', label='Biocapacity Deficit or Reserve')

# Add xticks on the middle of the group bars
plt.xlabel('group', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(bars1))], labels)
 
# Create legend & Show graphic
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-898-31c809217cc2> in <module>
#      12 bar4= top_10_GDPcountries["Biocapacity Deficit or Reserve"]
#      13 # Set position of bar on X axis
# ---> 14 r1 = np.arange(len(bars1))
#      15 r2 = [x + barWidth for x in r1]
#      16 r3 =[x + barWidth for x in r2]
#
# NameError: name 'bars1' is not defined

# %%
sort_top_ten_countries= df.sort_values(["Population (millions)"], ascending= [False])
top_ten_countries= sort_top_ten_countries[["Country","Population (millions)","Total Biocapacity","Total Ecological Footprint" ]].head(10)
top_ten_countries
# Out:
#                       Country  Population (millions)  Total Biocapacity  \
# 37                      China                1408.04               0.94
# 79                      India                1236.69               0.45
# 179  United States of America                 317.50               3.76
# 80                  Indonesia                 246.86               1.26
# 23                     Brazil                 198.66               9.08
# 130                  Pakistan                 179.16               0.35
# 127                   Nigeria                 168.83               0.70
# 13                 Bangladesh                 154.70               0.38
# 141        Russian Federation                 143.17               6.79
# 87                      Japan                 127.25               0.72
#
#      Total Ecological Footprint
# 37                         3.38
# 79                         1.16
# 179                        8.22
# 80                         1.58
# ...

# %%
def reginal_biocapacity_bar(df_region):
    fig= plt.figure()
    plt.style.use("seaborn-darkgrid")
    row= 0
    for elem in df_region.index:
        plt.figure(1,1,row+1)
        region= pd.DataFrame({'column':clean_col_name(df_region).columns, "value":df_region.iloc[row,:]})
        row+=1
        plt.bar(region["column"], region["value"], label= elem)
    plt.legend(fancybox=True, fontsize=18)
    plt.ylabel('Biocapacity')
    plt.title("Reginal Biocapacity",fontsize=22, fontweight= "bold" )
#     matplotlib.rc('axes', xsize=12)
    size=22
    params = {
          'figure.figsize': (15,8),
          'axes.labelsize': 20,
          'axes.titlesize': 22,
          'xtick.labelsize': size*0.75,
          'ytick.labelsize': size*0.75,
          'axes.titlepad': 25}
    plt.rcParams.update(params)
    return None
# reginal_biocapacity_bar(top_10_GDPcountries)

# %%
# labels = ['G1', 'G2', 'G3', 'G4', 'G5']
# men_means = [20, 34, 30, 35, 27]
# women_means = [25, 32, 34, 20, 25]

# x = np.arange(len(labels))  # the label locations
# width = 0.35  # the width of the bars

# fig, ax = plt.subplots()
# rects1 = ax.bar(x - width/2, men_means, width, label='Men')
# rects2 = ax.bar(x + width/2, women_means, width, label='Women')

# # Add some text for labels, title and custom x-axis tick labels, etc.
# ax.set_ylabel('Scores')
# ax.set_title('Scores by group and gender')
# ax.set_xticks(x)
# ax.set_xticklabels(labels)
# ax.legend()


# def autolabel(rects):
#     """Attach a text label above each bar in *rects*, displaying its height."""
#     for rect in rects:
#         height = rect.get_height()
#         ax.annotate('{}'.format(height),
#                     xy=(rect.get_x() + rect.get_width() / 2, height),
#                     xytext=(0, 3),  # 3 points vertical offset
#                     textcoords="offset points",
#                     ha='center', va='bottom')


# autolabel(rects1)
# autolabel(rects2)

# fig.tight_layout()

# plt.show()

# %%
labels= top_10_GDPcountries.index
GDP= top_10_GDPcountries["GDP per Capita"]
Biocapacity = top_10_GDPcountries["Total Biocapacity"]
Ecological= top_10_GDPcountries["Total Ecological Footprint"]

# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]


x= np.arange(len(labels))
width=.26 
fig, ax = plt.subplots()
rects1 = ax.bar([x + barWidth for x in r1], GDP, width, label='GDP per Capita')
rects2 = ax.bar([x + barWidth for x in r2], Biocapacity, width, label='Total Biocapacity')
rects3 = ax.bar([x + barWidth for x in r3], Ecological, width, label='Total Ecological Footprint')

ax.set_ylabel('Scores')
ax.set_title('Ecological Footprint for top two gdp per capita countries')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)
autolabel(rects3)

fig.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-902-f270ac096e45> in <module>
#       5
#       6 # Set position of bar on X axis
# ----> 7 r1 = np.arange(len(bars1))
#       8 r2 = [x + barWidth for x in r1]
#       9 r3 = [x + barWidth for x in r2]
#
# NameError: name 'bars1' is not defined

# %%
# import numpy as np
# import matplotlib.pyplot as plt
 
# # set width of bar
# barWidth = 0.20
 
# # set height of bar
# GDP= top_10_GDPcountries["GDP per Capita"]
# Biocapacity = top_10_GDPcountries["Total Biocapacity"]
# Ecological= top_10_GDPcountries["Total Ecological Footprint"]
 
# # Set position of bar on X axis
# r1 = np.arange(len(bars1))
# r2 = [x + barWidth for x in r1]
# r3 = [x + barWidth for x in r2]
 
# # Make the plot
# plt.bar(r1, GDP, color='#7f6d5f', width=barWidth, edgecolor='white', label='GDP per capita')
# plt.bar(r2, Biocapacity, color='#557f2d', width=barWidth, edgecolor='white', label="Total Biocapacity")
# plt.bar(r3, Ecological, color='#2d7f5e', width=barWidth, edgecolor='white', label='Total Ecological Footprint')
 
# # Add xticks on the middle of the group bars
# # plt.xlabel('group', fontweight='bold')
# # plt.xticks([r + barWidth for r in range(len(bars1))], ['A', 'B', 'C', 'D', 'E'])
 
# # Create legend & Show graphic
# plt.legend()
# plt.show()

# %%
countrycode= pd.read_csv('/Users/danait/documents/galvanize/capstone/global_ecological_footprint/data/three_country_code.csv', header= 0)
countrycode.head(5)
clean_col_name(countrycode, "Name", "Country")
clean_col_name(countrycode, "Code", "CountryCode")
countrycode.tail(20)
# Out:
#                                   Country CountryCode
# 229              Turks and Caicos Islands         TCA
# 230                                Tuvalu         TUV
# 231                                Uganda         UGA
# 232                               Ukraine         UKR
# 233                  United Arab Emirates         ARE
# 234                        United Kingdom         GBR
# 235              United States of America         USA
# 236  United States Minor Outlying Islands         UMI
# 237                               Uruguay         URY
# 238                            Uzbekistan         UZB
# 239                               Vanuatu         VUT
# 240     Venezuela, Bolivarian Republic of         VEN
# 241                              Viet Nam         VNM
# 242               Virgin Islands, British         VGB
# 243                  Virgin Islands, U.S.         VIR
# 244                     Wallis and Futuna         WLF
# ...

# %%
data2= df[['Country',"Region", 'Biocapacity Deficit or Reserve', "Total Biocapacity", "Total Ecological Footprint"]]
outlier_countries= data2.sort_values(["Total Biocapacity"],ascending= False).head(3)
outlier_countries.set_index("Country")
# Out:
#                       Region  Biocapacity Deficit or Reserve  \
# Country
# French Guiana  Latin America                          109.01
# Suriname       Latin America                           85.08
# Guyana         Latin America                           63.51
#
#                Total Biocapacity  Total Ecological Footprint
# Country
# French Guiana             111.35                        2.34
# Suriname                   89.33                        4.25
# Guyana                     66.58                        3.07

# %%
data2= df[['Country',"Region", 'Biocapacity Deficit or Reserve', "Total Biocapacity", "Total Ecological Footprint"]]
data3
data= data2.join(countrycode.set_index("Country"), on= "Country", how= 'left')
data.head(5)
# data.isna().sum()
data[(pd.isna(data['CountryCode'])== True)]

data.head(10)
# Out:
#         Country                    Region  Biocapacity Deficit or Reserve  \
# 0   Afghanistan  Middle East/Central Asia                           -0.30
# 1       Albania   Northern/Eastern Europe                           -1.03
# 2       Algeria                    Africa                           -1.53
# 3        Angola                    Africa                            1.61
# 5     Argentina             Latin America                            3.78
# 6       Armenia  Middle East/Central Asia                           -1.35
# 8     Australia              Asia-Pacific                            7.26
# 9       Austria            European Union                           -3.00
# 10   Azerbaijan  Middle East/Central Asia                           -1.46
# 11      Bahamas             Latin America                            2.71
#
#     Total Biocapacity  Total Ecological Footprint CountryCode
# 0                0.50                        0.79         AFG
# ...

# %%
#elimenate_oulier second heatmap graph 
outlier_countries= data.iloc[[62,160,75],:]
data.drop([62,160,75], inplace= True)
outlier_countries.set_indet("Country")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-953-84893d871492> in <module>
#       1 #elimenate_oulier second heatmap graph
#       2 outlier_countries= data.iloc[[62,160,75],:]
# ----> 3 data.drop([62,160,75], inplace= True)
#       4 outlier_countries.set_indet("Country")
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# ...

# %%
import branca.colormap as cm
import folium
import pandas as pd

# %%
country_geo = '/Users/danait/documents/galvanize/capstone/global_ecological_footprint/data/world-countries.json'
# Setup a folium map at a high-level zoom
map = folium.Map(location=[100, 0], zoom_start=4)
legend= 'Biocapacity Deficit or Reserve'
# choropleth maps bind Pandas Data Frames and json geometries.
#This allows us to quickly visualize data combinations
map.choropleth(geo_data=country_geo, data=data,
             columns=['Biocapacity Deficit or Reserve','CountryCode'],
             key_on='feature.id',
             name= "choropleth",
             fill_color='YlGn', fill_opacity=0.7, line_opacity=0.2,
             nan_fill_color= "white",
             legend_name=legend)

map
# Out:
# /Users/danait/opt/anaconda3/lib/python3.7/site-packages/folium/folium.py:415: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-624-146a61450906> in <module>
#      11              fill_color='YlGn', fill_opacity=0.7, line_opacity=0.2,
#      12              nan_fill_color= "white",
# ---> 13              legend_name=legend)
#      14
#      15 map
#
# ~/opt/anaconda3/lib/python3.7/site-packages/folium/folium.py in choropleth(self, *args, **kwargs)
#     416         )
#     417         from folium.features import Choropleth
# --> 418         self.add_child(Choropleth(*args, **kwargs))
#     419
#     420     def keep_in_front(self, *args):
#
# ...

# %%
# from IPython.display import HTML

# %%
#map

# %%
# Import libraries
import json
import pandas as pd
import folium
 

state_geo = country_geo
 

state_data = data
 
# Initialize the map:
m = folium.Map( location=[37, -102],zoom_start=2)
m.fit_bounds([[52.193636, -2.221575], [52.636878, -1.139759]])
# Add the color for the chloropleth:
m.choropleth(
 geo_data=state_geo,
 name='choropleth',
 data=state_data,
 columns=['CountryCode', 'Biocapacity Deficit or Reserve'],
 key_on='feature.id',
 fill_color='RdYlGn',
 nan_fill_color= "white",
 fill_opacity=0.7,
 line_opacity=0.2,
 legend_name='Biocapacity Deficit or Reserve'
)
folium.LayerControl().add_to(m)
 
# Save to html
#m.save('#292_folium_chloropleth_USA1.html')

# %%
m.save("newbiodef_res.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Save to html
# m.save("neg14to24.png")
m.create_map(path='map.html')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-545-5fe5ad4967f4> in <module>
#       1 #Save to html
#       2 # m.save("neg14to24.png")
# ----> 3 m.create_map(path='map.html')
#
# AttributeError: 'Map' object has no attribute 'create_map'

# %%
data[data['Total Biocapacity'] == data['Total Biocapacity'].max()]
# Out:
#    Country  Biocapacity Deficit or Reserve  Total Biocapacity  \
# 64   Gabon                           24.29              26.31
#
#     Total Ecological Footprint CountryCode
# 64                        2.02         GAB

# %%
# second heat map for biocapacity

# Import libraries
import json
import pandas as pd
import folium
 

state_geo = country_geo
 

state_data = data
 
# Initialize the map:
m = folium.Map( location=[37, -102],zoom_start=2)
m.fit_bounds([[52.193636, -2.221575], [52.636878, -1.139759]])
# Add the color for the chloropleth:
m.choropleth(
 geo_data=state_geo,
 name='choropleth',
 data=state_data,
 columns=['CountryCode', 'Total Biocapacity'],
 key_on='feature.id',
 fill_color='YlGnBu',
 nan_fill_color= "white",
 fill_opacity=0.7,
 line_opacity=0.2,
 legend_name='Total Biocapacity'
)
folium.LayerControl().add_to(m)
 
# Save to html
#m.save('#292_folium_chloropleth_USA1.html')

# %%
m.save("newbiocapheatmap.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Import libraries
import json
import pandas as pd
import folium
 
state_geo = country_geo
 

state_data = data
 
# Initialize the map:
m = folium.Map( location=[37, -102],zoom_start=2)
m.fit_bounds([[52.193636, -2.221575], [52.636878, -1.139759]])
# Add the color for the chloropleth:
m.choropleth(
 geo_data=state_geo,
 name='choropleth',
 data=state_data,
 columns=['CountryCode', 'Total Ecological Footprint'],
 key_on='feature.id',
 fill_color='OrRd',
 nan_fill_color= "white",
 fill_opacity=0.7,
 line_opacity=0.2,
 legend_name='Total Ecological Footprint'
)
folium.LayerControl().add_to(m)
 
# Save to html
#m.save('#292_folium_chloropleth_USA1.html')
m.save("ecolofp.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#3 graphs next to each other for total biocapacity, ecological footprint, and all together, 
sort_top10_reserve_countries= df.sort_values(["Biocapacity Deficit or Reserve"], ascending= False)
top_10_reserve_countries= sort_top10_reserve_countries[["Country","GDP per Capita","Total Biocapacity","Total Ecological Footprint","Biocapacity Deficit or Reserve" ]].set_index("Country").head(10)
top_10_reserve_countries
# Out:
#                GDP per Capita  Total Biocapacity  Total Ecological Footprint  \
# Country
# French Guiana        18313.00             111.35                        2.34
# Suriname              8190.70              89.33                        4.25
# Guyana                3269.46              66.58                        3.07
# Gabon                11989.00              26.31                        2.02
# Bolivia               2253.09              16.73                        2.96
# Congo                 1943.69              10.91                        1.29
# Mongolia              3736.07              15.66                        6.08
# Canada               52145.40              16.01                        8.17
# Uruguay              14238.10              10.32                        2.91
# Australia            66604.20              16.57                        9.31
#
#                Biocapacity Deficit or Reserve
# Country
# French Guiana                          109.01
# ...

# %%
#sort_top10_reserve_countries= df.sort_values(["Biocapacity Deficit or Reserve"], ascending= False)
top_10_defic_countries= sort_top10_reserve_countries[["Country","GDP per Capita","Total Biocapacity","Total Ecological Footprint","Biocapacity Deficit or Reserve" ]].set_index("Country").tail(10)
top_10_defic_countries
# Out:
#                       GDP per Capita  Total Biocapacity  \
# Country
# Oman                         22622.8               1.92
# Israel                       33718.9               0.35
# Belgium                      48053.3               1.19
# Trinidad and Tobago          18310.8               1.56
# Bahrain                      24299.0               0.58
# United Arab Emirates         40817.4               0.56
# Kuwait                       41830.5               0.55
# Singapore                    53122.4               0.05
# Qatar                        99431.5               1.24
# Luxembourg                  114665.0               1.68
#
#                       Total Ecological Footprint  \
# Country
# Oman                                        7.52
# Israel                                      6.22
# Belgium                                     7.44
# Trinidad and Tobago                         7.92
# Bahrain                                     7.49
# ...

# %%
#the same graph as above graph all three together
